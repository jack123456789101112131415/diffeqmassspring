# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialization
tstart = 0
tstop = 60
increment = 0.1

# Initial conditions
x_init_1 = [1, 0]  # Initial condition 1
x_init_2 = [0, 1]  # Initial condition 2
x_init_3 = [0, -1]  # Initial condition 3

t = np.arange(tstart, tstop + 1, increment)

# Function that returns dx/dt
def mydiff(x, t):
    k = 2  # Stiffness of the spring
    m = 20  # Mass
    F = 5
    dx1dt = x[1]
    dx2dt = (F - k * x[0]) / m
    dxdt = [dx1dt, dx2dt]
    return dxdt

# Solve ODE for each initial condition
x_1 = odeint(mydiff, x_init_1, t)
x_2 = odeint(mydiff, x_init_2, t)
x_3 = odeint(mydiff, x_init_3, t)

x1_1 = x_1[:, 0]
x2_1 = x_1[:, 1]
x1_2 = x_2[:, 0]
x2_2 = x_2[:, 1]
x1_3 = x_3[:, 0]
x2_3 = x_3[:, 1]

# Plot the Results
plt.figure(1)

plt.subplot(311)
plt.plot(t, x1_1)
plt.title('Simulation of Undamped Mass-Spring System (Initial Condition 1)')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()

plt.subplot(312)
plt.plot(t, x1_2)
plt.title('Simulation of Undamped Mass-Spring System (Initial Condition 2)')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()

plt.subplot(313)
plt.plot(t, x1_3)
plt.title('Simulation of Undamped Mass-Spring System (Initial Condition 3)')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()

plt.tight_layout()
plt.show()
